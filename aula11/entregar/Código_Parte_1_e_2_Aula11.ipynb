# %% [markdown]
# ### Atividade da Aula
#
# - **Aluno:** Augusto Mathias Adams
#
# #### Parte 1
#
# **Rode todo o código. Certifique-se que você o compreendeu.**
#
# Feito.
#
# #### Parte 2
#
# 1. **Explique, com as suas próprias palavras, quais são os passos necessários para implementar a Regressão Logı́stica na prática.**
#
# - **Caracterização do Problema:** primeiro, é preciso ter um problema caracterizado como regressão logística. A regressão logística é utilizada quando o objetivo é prever a probabilidade de um evento ocorrer, por exemplo, se um tumor é maligno ou não como no estudo de caso apresentado neste *notebook*.
# - **Coleta e Preparação dos dados:** para atingir este objetivo, é necessário ter dados que permitam calcular a probabilidade de ocorrência a partir de variáveis explicativas. A coleta destes dados é importante para que a solução do problema seja satisfatória.
#     - Tem-se as variáveis $x_i$, que são as variáveis explicativas ou características, normalizadas ou não, obtidas a partir da engenharia de características;
#     - A partir da engenharia de características, obtém-se uma função característica, do tipo $z = \beta_0 + \beta_1 \cdot x_1 + \beta_2 \cdot x_2 + \beta_3 \cdot x_3 + \dots + \beta_n \cdot x_n$, que será o argumento da função logística, responsável pelo cálculo da probabilidade de determinado evento ocorrer.
#     - Por fim, tem-se a variável $y$, que é a saída da função logística, resultando em um número entre 0 e 1, que é interpretado como a probabilidade do evento ocorrer ou não.
#     - O próximo passo consiste em dividir os dados disponíveis em conjuntos de treinamento e teste, de forma que o modelo possa aprender com uma parte dos dados e ser avaliado em outra. Em geral, essa divisão segue uma proporção como 70%-30% ou 80%-20%, dependendo da quantidade de dados disponível. Para a atividade de aula, não há divisão entre dados de treinamento e teste, entretanto este passo é necessário para avaliar a capacidade de generalização do modelo logístico, frente a casos não vistos durante a regressão.
#
# - **Treinamento:** o modelo de Regressão Logística é treinado utilizando os dados de treinamento. O objetivo é ajustar os coeficientes $ \beta_0, \beta_1, ..., \beta_n $ da função característica para que o modelo seja capaz de minimizar a função de perda (*log-loss* ou entropia cruzada) e ajustar-se aos dados de forma que as previsões reflitam as respostas reais.
#     - Embora a lógica por trás da regressão logística seja semelhante ao visto para regressão linear, a regressão logística não possui solução fechada através do método dos mínimos quadrados ou solução de sistemas, conforme visto na aula 2. Isto porque a função de custo não possui uma solução analítica de forma fechada (Goodfellow, 2016 - eu acho, estou escrevendo de memória... que não vai muito bem rs) ou mesmo única. Os algoritmos iterativos como o método do gradiente são utilizados para o treinamento da regressão logística.
#
# - **Avaliação:** o desempenho do modelo é avaliado usando os dados de teste. A avaliação pode ser feita com métricas como a acurácia, a matriz de confusão (para observar os acertos e erros em cada classe), e outras métricas derivadas, como *precisão*, *recall* e *F1-score*, para mensurar a capacidade do modelo de separar as classes.
#
# - **Ajustes:** se necessário, pode-se ajustar o modelo mais refinadamente, aplicando técnicas de regularização como $L1$ (*lasso*) ou $L2$ (*ridge*), ou realizar tuning de hiperparâmetros para melhorar o desempenho. Após o modelo estar ajustado e validado, ele pode ser aplicado em novos dados para prever a probabilidade de ocorrência de um evento com base nas variáveis explicativas fornecidas.
#
#
# 2. **Faça modificações no conjunto de dados que está no código, e verifique como essas modificações alteram a fronteira de decisão do modelo estimado**
#
# Claro! geraremos um conjunto de dados com ruído e testaremos com o método do gradiente visto em aulas anteriores, bem como daremos continuidade aos testes de outros algoritmos iterativos para a solução da regressão logística. Os resultados são sumarizados na seção **Happy Hour** deste notebook.
#
# - Otimização através dos algoritmos:
#     - Gradiente Descendente (Visto em Aula)
#     - Gradiente Descendente (Versão GDC - *"Gugu Das Candonga"*)
#     - RMSProp (Versão GDC - *"Gugu Das Candonga"*)
#     - SGD (Gradiente Estocástico - Versão GDC - *"Gugu Das Candonga"*)
#     - Gradiente Conjugado (Versão GDC - *"Gugu Das Candonga"*)
#     - Adam (Versão GDC - *"Gugu Das Candonga"*)
#     - LogisticRegressor do pacote **sklearn**
# - Condições de treino e teste
#     - Para treino, são geradas de forma aleatória 5000 amostras limitadas a um quadrado de coordenadas [(0, 0), ($x_0$,0), ($x_0$, $x_1$), (0, $x_1$)], classificados com a fronteira de decisão dada pela função $f_{\mathbf{w},b}(x^{(i)}) = \frac{1}{1 + e^{-z}}$, sendo $z = w \cdot x + b$, com $w = \left[5.28123029, 5.07815608\right]$ e $b =-14.222409982019837$. Após a geração da classificação (tabela verdade), foi adicionado ruído gaussiano com $\mu = 0$ e $\sigma = 0.05$, para corromper as variáveis explicativas em torno da fronteira de decisão.
#     - Mesmo procedimento é adotado para a geração dos dados de teste, com uma semente aleatória diferente - simulação de dados não vistos.
#     - Ao todo, foram geradas 10000 amostras para treino e teste, com sementes aleatórias distintas, corrompidas com a adição de ruído gaussiano de $\mu = 0.0$ e $\sigma = 0.05$.
# - Performance da Otimização:
#
# | Algoritmo                  |   $T_e$(s) |   $N$ |   $\frac{T_e}{N}$ |      $b$ |    $w_0$ |    $w_1$ |     $b_n$ |   $w_{0_n}$ |   $w_{1_n}$ |
# |:---------------------------|-----------:|------:|------------------:|---------:|---------:|---------:|----------:|------------:|------------:|
# | Método do Gradiente (Aula) | 354.53     | 10000 |       0.035453    | -25.1528 |  9.33689 |  8.93964 | -0.88942  |    0.330159 |    0.316112 |
# | Método do Gradiente (GDC)  |   8.69583  | 10000 |       0.000869583 | -25.1528 |  9.33689 |  8.93964 | -0.88942  |    0.330159 |    0.316112 |
# | RMSProp                    |   0.696367 |  1000 |       0.000696367 | -29.9213 | 11.0644  | 10.588   | -0.890179 |    0.329174 |    0.315001 |
# | SGD                        |  89.9936   |   500 |       0.179987    | -19.7944 |  7.34557 |  7.03643 | -0.889434 |    0.330063 |    0.316172 |
# | Gradiente Conjugado        |   2.17976  |  2000 |       0.00108988  | -14.1491 |  5.25376 |  5.04063 | -0.889183 |    0.330165 |    0.316772 |
# | Adam                       |   0.695039 |  1000 |       0.000695039 | -21.4891 |  7.9793  |  7.64231 | -0.889335 |    0.330226 |    0.31628  |
# | SKLearn                    |   0.141426 |    14 |       0.0101018   | -29.1301 | 10.7995  | 10.3417  | -0.889643 |    0.32982  |    0.31584  |
# - Discussão:
#     - Eficiência Temporal:
#     O tempo total de execução ($T_e$) varia significativamente entre os algoritmos. O **Método do Gradiente (Aula)** tem o maior tempo de execução (329.79 segundos), enquanto o **SKLearn** é o mais rápido (0.012 segundos).
#     O tempo médio por iteração ($\frac{T_e}{N}$) também reflete a eficiência dos algoritmos:
#         - **SKLearn** tem o tempo médio por iteração mais alto (0.01 s), sugerindo que mesmo com um número menor de iterações, é altamente eficiente.
#         - **Método do Gradiente (GDC)**, com um tempo médio por iteração de 0.0008 s, é quase tão eficiente quanto, mas usa 10.000 iterações, o que reflete uma boa convergência com um alto número de iterações.
#
#     - Comportamento dos Parâmetros:
#         - Os valores de $w_0$, $w_1$ e $b$ são bastante consistentes entre os algoritmos antes da normalização, sugerindo que diferentes algoritmos alcançam soluções similares em termos de coeficientes da regressão.
#         - Após a normalização (colunas $b_n$, $w_{0_n}$, $w_{1_n}$), os valores também permanecem consistentes entre os algoritmos.
#
#     - Método do Gradiente (Aula) vs Método do Gradiente (GDC):
#     Ambos utilizam o mesmo número de iterações (10.000), e os parâmetros $w_0$, $w_1$ e $b$ são idênticos. No entanto, há uma grande diferença no tempo total de execução:
#         - **Método do Gradiente (Aula)** leva 354.53 segundos, enquanto o **Método do Gradiente (GDC)** leva apenas 8.7 segundos. Isso sugere uma implementação mais eficiente no caso do GDC (que utiliza vetorização nas funções de perda e cálculo do gradiente).
#
#     - Comparação entre Algoritmos:
#         - **RMSProp** e **Adam** têm tempos de execução baixos, e seus tempos médios por iteração são comparáveis (0.0007 s e 0.0007 s, respectivamente). Isso reflete a eficiência desses algoritmos de otimização em alcançar soluções rapidamente com um número moderado de iterações.
#         - **Gradiente Conjugado** também apresenta um bom desempenho em termos de tempo por iteração (0.00011 s), sendo eficiente no número de iterações.
#         - **SGD** tem um tempo médio por iteração muito alto (0.18 s), o que o torna o menos eficiente dentre os algoritmos, mesmo levando em conta seu menor número de iterações (500).
#
#     - Conclusões:
#         - **Eficiência**: O **Método do Gradiente (Aula)** tem o pior desempenho em termos de tempo total de execução, enquanto **SKLearn** é o mais rápido. No entanto, em termos de eficiência por iteração, **SKLearn** não é o mais eficiente, sendo superado por algoritmos como **Método do Gradiente (GDC)**, **RMSProp**, e **Adam**.
#         - **Consistência dos Parâmetros**: Os parâmetros $w_0$, $w_1$ e $b$, tanto antes quanto depois da normalização, são bastante consistentes entre todos os algoritmos, o que indica que diferentes métodos de otimização convergem para soluções muito similares, reforçando que a escolha do algoritmo de otimização impacta mais o tempo de execução do que a precisão dos coeficientes.
#         - **Escolha de Algoritmo**: Algoritmos como **Adam**, **RMSProp**, e **Gradiente Conjugado** se mostram boas escolhas para otimização em termos de balanceamento entre tempo total de execução e tempo por iteração, sendo muito mais eficientes do que o **SGD** e o **Método do Gradiente (Aula)**.
#
# - Parâmetros de Desempenho:
#
# | Algoritmo                  | Classe        |   $T_P$ |   $F_P$ |   $F_N$ |   $P(\%)$ |   $R(\%)$ |   $F_1$ Score |
# |:---------------------------|:--------------|--------:|--------:|--------:|----------:|----------:|--------------:|
# | Método do Gradiente (Aula) | Tumor Benigno |    2588 |      50 |      55 |      98.1 |      97.9 |             1 |
# | Método do Gradiente (Aula) | Tumor Maligno |    2307 |      55 |      50 |      97.7 |      97.9 |             1 |
# | Método do Gradiente (GDC)  | Tumor Benigno |    2588 |      50 |      55 |      98.1 |      97.9 |             1 |
# | Método do Gradiente (GDC)  | Tumor Maligno |    2307 |      55 |      50 |      97.7 |      97.9 |             1 |
# | RMSProp                    | Tumor Benigno |    2600 |      63 |      43 |      97.6 |      98.4 |             1 |
# | RMSProp                    | Tumor Maligno |    2294 |      43 |      63 |      98.2 |      97.3 |             1 |
# | SGD                        | Tumor Benigno |    2587 |      50 |      56 |      98.1 |      97.9 |             1 |
# | SGD                        | Tumor Maligno |    2307 |      56 |      50 |      97.6 |      97.9 |             1 |
# | Gradiente Conjugado        | Tumor Benigno |    2585 |      48 |      58 |      98.2 |      97.8 |             1 |
# | Gradiente Conjugado        | Tumor Maligno |    2309 |      58 |      48 |      97.5 |      98   |             1 |
# | Adam                       | Tumor Benigno |    2587 |      50 |      56 |      98.1 |      97.9 |             1 |
# | Adam                       | Tumor Maligno |    2307 |      56 |      50 |      97.6 |      97.9 |             1 |
# | SKLearn                    | Tumor Benigno |    2590 |      52 |      53 |      98   |      98   |             1 |
# | SKLearn                    | Tumor Maligno |    2305 |      53 |      52 |      97.8 |      97.8 |             1 |
# -  Desempenho Geral dos Algoritmos:
#     - Todos os algoritmos apresentam **F1-Score de 1**, o que indica um excelente equilíbrio entre **Precisão** e **Recall**.
#     - As variações em $ P (\%) $ (Precisão) e $ R (\%) $ (Recall) entre os algoritmos são mínimas, sugerindo que **todos os métodos de otimização são equivalentes** no problema de classificação entre tumores benignos e malignos.
# - Comparação de Precisão e Recall:
#     - **Tumor Benigno**:
#         - A **Precisão** ($ P (\%) $) varia entre 97.6% e 98.2%, mostrando uma alta proporção de previsões corretas para essa classe.
#         - O **Recall** ($ R (\%) $) está consistentemente próximo de 98%, sugerindo que os tumores benignos verdadeiros são bem detectados.
#
#     - **Tumor Maligno**:
#         - A **Precisão** varia entre 97.5% e 98.2%, mostrando uma alta exatidão nas previsões dessa classe.
#         - O **Recall** é consistente, variando entre 97.3% e 98.0%, o que demonstra que a maioria dos tumores malignos verdadeiros são detectados.
# - Diferenças Pequenas entre Algoritmos:
#     - **RMSProp** tem um **Recall** ligeiramente maior para **Tumor Benigno** (98.4%), enquanto o **Gradiente Conjugado** tem a maior **Precisão** (98.2%) para essa classe.
#
# - Comportamento Uniforme:
#     - Como as métricas são muito semelhantes, podemos concluir que **todos os métodos de otimização oferecem desempenho quase idêntico** para este problema de classificação.
#
# - Falsos Positivos e Falsos Negativos:
#     - O número de **falsos positivos** ($ F_P $) e **falsos negativos** ($ F_N $) é baixo para todos os algoritmos e classes, sugerindo **um bom ajuste dos modelos**.
#
# - Conclusão Final:
#     - Todos os algoritmos se mostram eficazes para a classificação de tumores benignos e malignos. Dependendo da preferência por **Precisão** ou **Recall** ligeiramente superiores, o **Gradiente Conjugado** pode ser preferido para tumores benignos, e o **RMSProp** para tumores malignos, mas na prática, qualquer um dos algoritmos pode ser utilizado.

# %% [markdown]
# # Regressão Logística
#
# ## Objetivos
#
# Com este código, você irá:
# - Implementar o método de Regressão Logística "na mão" e comparar com os resultados obtidos por meio da biblioteca Scikit-Learn.

# %%
# %pip install seaborn
# %pip install tabulate
import math
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from tabulate import tabulate
import time
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Conjunto de dados
#
# O conjunto de dados usado nesse código é o mesmo já utilizado na atividade de programação anterior.

# %%
X_trein = np.array([[0.5, 1.5], [1,1], [1.5, 0.5], [3, 0.5], [2, 2], [1, 2.5]])  #(m,n)
y_trein = np.array([0, 0, 0, 1, 1, 1])                                           #(m,)

# %% [markdown]
# Plotando os dados:

# %%
pos = y_trein == 1 # identifica os elementos em y que são iguais a 1
neg = y_trein == 0 # identifica os elementos em y que são iguais a 0

fig,ax = plt.subplots(1,1,figsize=(10,8))
ax.scatter(X_trein[pos,0], X_trein[pos,1], marker='x', s=80, c = 'red', label="y=1")
ax.scatter(X_trein[neg,0], X_trein[neg,1], marker='o', s=100, label="y=0", facecolors='none',
              edgecolors='b',lw=3)

ax.axis([0, 4, 0, 3.5])
ax.set_ylabel('$x_1$')
ax.set_xlabel('$x_0$')
ax.legend()
plt.show()

# %% [markdown]
# ## Plotando a Fronteira de Decisão para o modelo com $w_0=1$, $w_1=1$ e $b=-3$
#
# Na atividade anterior, vimos que a Fronteira de decisão para esse modelo é conforme abaixo:

# %%
# Escolhendo valores entre 0 e 6
x0 = np.arange(0,6)

x1 = 3 - x0
fig,ax = plt.subplots(1,1,figsize=(10,8))

# Plotando a Fronteira de Decisão
ax.plot(x0,x1, c="b")
ax.axis([0, 4, 0, 3.5]) # limitando o display do gráfico

# Preenche a região abaixo da linha
ax.fill_between(x0,x1, alpha=0.2)

# Plotando os dados também:
ax.scatter(X_trein[pos,0], X_trein[pos,1], marker='x', s=80, c = 'red', label="y=1")
ax.scatter(X_trein[neg,0], X_trein[neg,1], marker='o', s=100, label="y=0", facecolors='none',
              edgecolors='b',lw=3)

ax.set_ylabel('$x_1$')
ax.set_xlabel('$x_0$')
plt.show()

# %% [markdown]
# ## Uma outra possibilidade de modelo: modelo com $w_0=1$, $w_1=1$ e $b=-4$
#
# Nesse caso, a fronteira de decisão torna-se $x_0 + x_1 = 4$. Abaixo plotamos ela.

# %%
# Escolhendo valores entre 0 e 6
x0 = np.arange(0,6)

x1 = 4 - x0
fig,ax = plt.subplots(1,1,figsize=(10,8))

# Plotando a Fronteira de Decisão
ax.plot(x0,x1, c="b")
ax.axis([0, 4, 0, 3.5]) # limitando o display do gráfico

# Preenche a região abaixo da linha
ax.fill_between(x0,x1, alpha=0.2)

# Plotando os dados também:
ax.scatter(X_trein[pos,0], X_trein[pos,1], marker='x', s=80, c = 'red', label="y=1")
ax.scatter(X_trein[neg,0], X_trein[neg,1], marker='o', s=100, label="y=0", facecolors='none',
              edgecolors='b',lw=3)

ax.set_ylabel('$x_1$')
ax.set_xlabel('$x_0$')
plt.show()

# %% [markdown]
# Qual modelo você acha que apresentará **um menor custo** $J(\mathbf{w},b)$?
# - O modelo com $w_0=1$, $w_1=1$ e $b=-3$?
# - Ou o modelo com $w_0=1$, $w_1=1$ e $b=-4$?
#
# Vamos checar isso implementando a função custo para Regressão Logística

# %% [markdown]
# ## Função Custo
#
# Na Regressão Logística, a função custo tem a forma
#
# $$ J(\mathbf{w},b) = \frac{1}{m} \sum_{i=0}^{m-1} \left[ perda(f_{\mathbf{w},b}(\mathbf{x}^{(i)}), y^{(i)}) \right] \tag{1}$$
#
# onde
# * $perda(f_{\mathbf{w},b}(\mathbf{x}^{(i)}), y^{(i)})$ é o custo associado a uma única amostra de dados, que é:
#
#     $$perda(f_{\mathbf{w},b}(\mathbf{x}^{(i)}), y^{(i)}) = -y^{(i)} \log\left(f_{\mathbf{w},b}\left( \mathbf{x}^{(i)} \right) \right) - \left( 1 - y^{(i)}\right) \log \left( 1 - f_{\mathbf{w},b}\left( \mathbf{x}^{(i)} \right) \right) \tag{2}$$
#
# *  m é o número de amostras de treinamento e:
# $$
# \begin{align}
#   f_{\mathbf{w},b}(\mathbf{x^{(i)}}) &= g(z^{(i)})\tag{3} \\
#   z^{(i)} &= \mathbf{w} \cdot \mathbf{x}^{(i)}+ b\tag{4} \\
#   g(z^{(i)}) &= \frac{1}{1+e^{-z^{(i)}}}\tag{5}
# \end{align}
# $$

# %% [markdown]
# #### Descrição do Código abaixo:
#
# A função `calcula_custo_RegLog` abaixo faz um loop passando por todas as amostras e calculando a perda para cada exemplo.
# O total então é computado e depois divido por m.
#
# Note que as variáveis X e y não são escalares mas sim matrizes de shape ($m, n$) e ($𝑚$,) respectivamente, onde  $𝑛$ é o número de características e $𝑚$ é o número de amostras de treinamento.

# %%
def calcula_custo_RegLog(X, y, w, b):
    """
    Calcula a função custo para Regressão Logística

    Argumentos:
      X (ndarray (m,n)): Dados, m exemplos com n características
      y (ndarray (m,)) : valores alvo
      w (ndarray (n,)) : parâmetros do modelo
      b (escalar)      : parâmetro do modelo

    Retorna:
      custo (escalar): custo
    """

    m = X.shape[0]
    custo = 0.0
    for i in range(m):
        z_i = np.dot(X[i],w) + b
        f_wb_i = sigmoide(z_i)
        custo +=  -y[i]*np.log(f_wb_i) - (1-y[i])*np.log(1-f_wb_i)

    custo = custo / m
    return custo

def sigmoide(z):
    """
    Calcula o valor sigmoide de z

    Argumento:
        z (ndarray): Um escalar ou numpy array de qualquer tamanho.

    Retorna:
        g (ndarray): sigmoid(z), com o mesmo shape de z

    """

    g = 1/(1+np.exp(-z))

    return g

# funções que produzi na aula 10, somente para comparar resultados

def calcula_perda_gdc(x, y, w, b): # gdc = versão Gugu Das Candonga
    """
        Função perda
        Args:
            x (ndarray): valores da variável independente
            y (ndarray): valores da variável independente
            w (float): valor do coeficiente angular
            b (float): valor do intercepto
        Returns:
            perdas (ndarray): as perdas associadas aos parâmetros w e b em cada ponto
    """

    z = np.dot(x, w) + b
    y_est = sigmoide(z) 
    perdas = - (y * np.log(y_est) + (1 - y) * np.log(1 - y_est))
    return perdas


def calcula_custo_gdc(x, y, w, b): # gdc = versão Gugu Das Candonga
    """
        Calcula o custo em função da perda
        Args:
            x (ndarray): valores da variável independente
            y (ndarray): valores da variável independente
            w (ndarray): valor do coeficiente angular
            b (float): valor do intercepto
        Returns:
            perdas (ndarray): as perdas associadas aos parâmetros w e b em cada ponto
    """
    n = len(y) 
    perdas_totais = np.sum(calcula_perda_gdc(x, y, w, b))
    
    return perdas_totais / n

# %% [markdown]
# ### Checando nossa implementação calculando o custo para o modelo com $w_0=1$, $w_1=1$ e $b=-3$

# %%
w_tmp = np.array([1,1])
b_tmp = -3
print(calcula_custo_RegLog(X_trein, y_trein, w_tmp, b_tmp))
print(calcula_custo_gdc(X_trein, y_trein, w_tmp, b_tmp))
# Out:
# 0.36686678640551745
# 0.36686678640551745

# %% [markdown]
# **Valor Esperado**: 0.3668667864055175

# %% [markdown]
# ### Checando nossa implementação calculando o custo para o modelo com $w_0=1$, $w_1=1$ e $b=-4$

# %%
w_tmp = np.array([1,1])
b_tmp = -4
print(calcula_custo_RegLog(X_trein, y_trein, w_tmp, b_tmp))
print(calcula_custo_gdc(X_trein, y_trein, w_tmp, b_tmp))
# Out:
# 0.503680863674846
# 0.503680863674846

# %% [markdown]
# **Valor Esperado**: 0.5036808636748461

# %% [markdown]
# # Método do Gradiente: Calculando o nosso próprio modelo

# %% [markdown]
# Lembre-se que o Método do Gradiente implementa a seguinte lógica:
# $$\begin{align*}
# &\text{repetir até convergir:} \; \lbrace \\
# &  \; \; \;w_j = w_j -  \alpha \frac{\partial J(\mathbf{w},b)}{\partial w_j} \tag{1}  \; & \text{for j := 0..n-1} \\
# &  \; \; \;  \; \;b = b -  \alpha \frac{\partial J(\mathbf{w},b)}{\partial b} \\
# &\rbrace
# \end{align*}$$
#
# Onde cada iteração performa atualização simultanea de $w_j$ para todo $j$ e para $b$, onde
# $$\begin{align*}
# \frac{\partial J(\mathbf{w},b)}{\partial w_j}  &= \frac{1}{m} \sum\limits_{i = 0}^{m-1} (f_{\mathbf{w},b}(\mathbf{x}^{(i)}) - y^{(i)})x_{j}^{(i)} \tag{2} \\
# \frac{\partial J(\mathbf{w},b)}{\partial b}  &= \frac{1}{m} \sum\limits_{i = 0}^{m-1} (f_{\mathbf{w},b}(\mathbf{x}^{(i)}) - y^{(i)}) \tag{3}
# \end{align*}$$
#
# * $f_{\mathbf{w},b}(x^{(i)})$ é a previsão feita pelo modelo, sendo $y^{(i)}$ o alvo
# * Para o modelo de Regressão Logística:
#     $z = \mathbf{w} \cdot \mathbf{x} + b$
#     $f_{\mathbf{w},b}(x) = g(z)$
#     sendo $g(z)$ a função sigmoide:
#     $g(z) = \frac{1}{1+e^{-z}}$

# %% [markdown]
# ## Implementação do Método do Gradiente:
#
# O algoritmo do Método do Gradiente possui duas componentes:
# - O loop que implementa a equação (1) acima. Essa é a função metodo_do_gradiente_RegLog abaixo.
# - O cálculo do gradiente atual, dado pelas equações (2) e (3) acima. Essa é a função calcula_gradiente_RegLog abaixo.
#
# #### Cálculo do gradiente: descrição do código:
# Implementa as equações (2) e (3) acima para todo $w_j$ e $b$.
#
# Há muitas formas para se implementar isso. Abaixo fazemos da seguinte maneira:
# - Inicializamos as variáveis para acumular `dj_dw` e `dj_db`
# - Para cada exemplo:
#     - Calcula-se o erro para esse exemplo, $g(\mathbf{w} \cdot \mathbf{x}^{(i)} + b) - \mathbf{y}^{(i)}$
#     - Para cada valor de entrada $x_{j}^{(i)}$ nesse exemplo,
#         - multiplica o erro pela entrada  $x_{j}^{(i)}$, e adiciona para o elemento correspondente de `dj_dw`. (Equação 2 acima)
#     - adiciona o erro para `dj_db` (Equação 3 acima)
#
# - divide-se `dj_db` e `dj_dw` pelo número total de amostras (m)
# - Note que $\mathbf{x}^{(i)}$ em Numpy é `X[i,:]` ou `X[i]`  e que $x_{j}^{(i)}$ é `X[i,j]`

# %%
def calcula_gradiente_RegLog(X, y, w, b):
    """
    Calcula Gradiente para Regressão Linear
    Argumentos:
      X (ndarray (m,n)): Dados, contendo m exemplos com n características
      y (ndarray (m,)) : valores alvo
      w (ndarray (n,)) : parâmetros w do modelo
      b (scalar)       : parâmetro b do modelo

    Retorna:
      dj_dw (ndarray (n,)): O gradiente da função custo com relação aos parâmetros w.
      dj_db (escalar):      O gradiente da função custo com relação ao parâmetro b.
    """
    m,n = X.shape
    dj_dw = np.zeros((n,))                           #(n,)
    dj_db = 0.

    for i in range(m):
        f_wb_i = sigmoide(np.dot(X[i],w) + b)          #(n,)(n,)=escalar
        err_i  = f_wb_i  - y[i]                       #escalar
        for j in range(n):
            dj_dw[j] = dj_dw[j] + err_i * X[i,j]      #escalar
        dj_db = dj_db + err_i
    dj_dw = dj_dw/m                                   #(n,)
    dj_db = dj_db/m                                   #escalar

    return dj_db, dj_dw


def calcula_gradiente_gdc(x, y, w, b): # gdc = versão Gugu Das Candonga
    """
    Calcula Gradiente para Regressão Linear
    Args:
      x(ndarray): Dados, contendo m exemplos com n características
      y (ndarray) : valores alvo
      w (ndarray) : parâmetros w do modelo
      b (float) : parâmetro b do modelo

    Retorna:
      dj_dw (float): O gradiente da função custo com relação aos parâmetros w.
      dj_db (float): O gradiente da função custo com relação ao parâmetro b.
    """
    n = len(x) 
    z = np.dot(x, w) + b
    y_est = sigmoide(z) 

    erro = y_est - y

    dj_dw = (1/n) * np.dot(x.T, erro)

    dj_db = (1/n) * np.sum(erro)

    return dj_db, dj_dw

# %% [markdown]
# Checando a nossa implementação do gradiente:

# %%
X_tmp = np.array([[0.5, 1.5], [1,1], [1.5, 0.5], [3, 0.5], [2, 2], [1, 2.5]])
y_tmp = np.array([0, 0, 0, 1, 1, 1])
w_tmp = np.array([2.,3.])
b_tmp = 1.
dj_db_tmp, dj_dw_tmp = calcula_gradiente_RegLog(X_tmp, y_tmp, w_tmp, b_tmp)
print(f"dj_db: {dj_db_tmp}" )
print(f"dj_dw: {dj_dw_tmp.tolist()}" )
dj_db_tmp, dj_dw_tmp = calcula_gradiente_gdc(X_tmp, y_tmp, w_tmp, b_tmp)
print(f"dj_db (gdc): {dj_db_tmp}" )
print(f"dj_dw (gdc): {dj_dw_tmp.tolist()}" )
# Out:
# dj_db: 0.49861806546328574
# dj_dw: [0.498333393278696, 0.49883942983996693]
# dj_db (gdc): 0.49861806546328574
# dj_dw (gdc): [0.498333393278696, 0.4988394298399669]

# %% [markdown]
# **Valor esperado**
# ```
# dj_db: 0.49861806546328574
# dj_dw: [0.498333393278696, 0.49883942983996693]
# ```

# %% [markdown]
# #### Método do Gradiente: descrição do código
#
# O código que implementa a Equação (1) acima é fornecido abaixo. Tire um momento para entender o que está sendo calculado e como isso é feito.

# %%
def metodo_do_gradiente_RegLog(X, y, w_inicial, b_inicial, alpha, num_iters):
    """
    Performa Método do Gradiente para aprender theta. Atualiza theta ao longo de
    num_iters passos de iteração usando uma taxa de aprendizado alpha

    Argumentos
      X (ndarray (m,n))   : Dados, contendo m exemplos com n características
      y (ndarray (m,))    : valores alvo
      w_inicial (ndarray (n,)) : valores iniciais dos parâmetros w do modelo
      b_inicial (escalar)      : valor inicial do parâmetro b do modelo
      alpha (float)       : taxa de aprendizado
      num_iters (int)     : Número de iterações para o método do gradiente

    Retorna:
      w (ndarray (n,)) : Valores atualizados para os parâmetros w
      b (escalar)      : Valores atualizado para o parâmetro b
      """

    w = w_inicial
    b = b_inicial

    # Valores históricos
    J_his = []

    for i in range(num_iters):
        # Calculando o gradiente
        dj_db, dj_dw = calcula_gradiente_RegLog(X, y, w, b)

        # Atualizando os parâmetros com base em alpha e nos gradientes
        w = w - alpha * dj_dw
        b = b - alpha * dj_db

        # Salva J para cada iteração
        if i<100000:
            J_his.append( calcula_custo_RegLog(X, y, w, b) )

        # Armazena Custo de tempos em tempos para plotar depois
        if i% math.ceil(num_iters / 10) == 0:
            print(f"Iteração {i:4d}: Custo {J_his[-1]}   ")

    return w, b, J_his         #retorna os valores finais w,b e J history para plotar curva de aprendizado

# método do intrépido Gugu Das Candonga


def metodo_do_gradiente_gdc(X, y, w_in, b_in, calcula_custo, calcula_gradiente, alpha, num_iters):
    """
    Performa Método do Gradiente para aprender theta. Atualiza theta ao longo de
    num_iters passos de iteração usando uma taxa de aprendizado alpha

    Args:
      X (ndarray (m,n))   : Dados, contendo m exemplos com n características
      y (ndarray (m,))    : valores alvo
      w_in (ndarray (n,)) : valores iniciais dos parâmetros w do modelo
      b_in (escalar)      : valor inicial do parâmetro b do modelo
      calcula_custo       : função que calcula o custo
      calcula_gradiente   : função que calcula o gradiente
      alpha (float)       : taxa de aprendizado
      num_iters (int)     : Número de iterações para o método do gradiente

    Retorna:
      w (ndarray (n,)) : Valores atualizados para os parâmetros w
      b (scalar)       : Valores atualizado para o parâmetro b
      """

    # Valores históricos
    J_history = []
    w = w_in
    b = b_in

    for i in range(num_iters):

        # Calcula o gradiente
        dj_db,dj_dw = calcula_gradiente(X, y, w, b)

        # Atualiza os parâmetros
        w = w - alpha * dj_dw
        b = b - alpha * dj_db

        # Salva o custo
        if i<100000:
            J_history.append( calcula_custo(X, y, w, b))

        # Faz print de tempos em tempos
        if i% math.ceil(num_iters / 10) == 0:
            print(f"Iteração {i:4d}: Custo {J_history[-1]:8.8f}   ")

    return w, b, J_history # retorna valores finais e históricos

# %% [markdown]
# Vamos agora rodar a Regressão Logística para os nossos dados

# %%
w_tmp     = np.zeros_like(X_trein[0])
b_tmp     = 0.
alpha     = 0.1
iteracoes = 10000

w_final, b_final, _ = metodo_do_gradiente_RegLog(X_trein, y_trein, w_tmp, b_tmp, alpha, iteracoes)
print(f"\nparâmetros finais: w:{w_final}, b:{b_final}")
print()
w_final_gdc, b_final_gdc, _ = metodo_do_gradiente_gdc(X_trein, y_trein, w_tmp, b_tmp, calcula_custo_gdc, calcula_gradiente_gdc, alpha, iteracoes)
print(f"\nparâmetros finais (gdc): w:{w_final_gdc}, b:{b_final_gdc}")
# Out:
# Iteração    0: Custo 0.6846104685605737
# Iteração 1000: Custo 0.1590977666870457
# Iteração 2000: Custo 0.08460064176930078
# Iteração 3000: Custo 0.0570532727940253
# Iteração 4000: Custo 0.042907594216820076
# Iteração 5000: Custo 0.034338477298845684
# Iteração 6000: Custo 0.028603798022120097
# Iteração 7000: Custo 0.02450156960879306
# Iteração 8000: Custo 0.021423703325692933
# Iteração 9000: Custo 0.019030137124109114
#
# parâmetros finais: w:[5.28123029 5.07815608], b:-14.222409982019837
#
# Iteração    0: Custo 0.68461047
# Iteração 1000: Custo 0.15909777
# Iteração 2000: Custo 0.08460064
# Iteração 3000: Custo 0.05705327
# Iteração 4000: Custo 0.04290759
# Iteração 5000: Custo 0.03433848
# Iteração 6000: Custo 0.02860380
# Iteração 7000: Custo 0.02450157
# Iteração 8000: Custo 0.02142370
# Iteração 9000: Custo 0.01903014
#
# parâmetros finais (gdc): w:[5.28123029 5.07815608], b:-14.222409982019837

# %% [markdown]
# **Note que o custo final é menor do que aquele que havia sido obtido com o modelo com $w_0=1$, $w_1=1$ e $b=-3$**

# %% [markdown]
# ## Plotando os resultados do método do gradiente:

# %%
# Fronteira de decisão
x0 = -b_final/w_final[0]
x1 = -b_final/w_final[1]

fig,ax = plt.subplots(1,1,figsize=(10,8))

# Plotando a Fronteira de Decisão
ax.plot([0,x0],[x1,0], c="b")
ax.axis([0, 4, 0, 3.5]) # limitando o display do gráfico

# Preenche a região abaixo da linha
ax.fill_between([0,x0],[x1,0], alpha=0.2)

# Plotando os dados também:
ax.scatter(X_trein[pos,0], X_trein[pos,1], marker='x', s=80, c = 'red', label="y=1")
ax.scatter(X_trein[neg,0], X_trein[neg,1], marker='o', s=100, label="y=0", facecolors='none',
              edgecolors='b',lw=3)

ax.set_ylabel('$x_1$')
ax.set_xlabel('$x_0$')
plt.show()

# %% [markdown]
# # Usando a biblioteca Scikit-Learn e comparando os resultados

# %% [markdown]
# ## Estimando o modelo:
#
# O código abaixo importa a função [logistic regression model](https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LogisticRegression.html#sklearn.linear_model.LogisticRegression) do scikit-learn. Você pode ajustar o modelo para os dados de treinamento chamando a função `fit`.

# %%
from sklearn.linear_model import LogisticRegression

modelo_RegLog = LogisticRegression()
modelo_RegLog.fit(X_trein, y_trein)
# Out:
# LogisticRegression()

# %% [markdown]
# ## Fazendo previsões:
#
# Você pode ver as previsões feitas por este modelo chamando a função `predict`.

# %%
y_pred = modelo_RegLog.predict(X_trein)

print("Previsão feita para os dados de treinamento:", y_pred)
# Out:
# Previsão feita para os dados de treinamento: [0 0 0 1 1 1]

# %% [markdown]
# ## Calculando Taxa de acerto do modelo (acurácia)
#
# Você pode calcular a taxa de acerto (acurácia) do modelo usando a função `score`. A acurácia corresponde ao percentual de amostras que foram corretamente classificadas pelo modelo.

# %%
print("Taxa de acerto para os dados de treinamento (%):", 100*modelo_RegLog.score(X_trein, y_trein))
# Out:
# Taxa de acerto para os dados de treinamento (%): 100.0

# %% [markdown]
# ## Parabéns!
#
# Com este código você implementou o algoritmo de Regressão Logística.

# %% [markdown]
# #### Happy Hour

# %% [markdown]
# ##### Parâmetros de Desempenho
#
# Texto extraído da monografia de meu TCC: [DETECTOR DE DESCARGAS ATMOSFÉRICAS PARA SISTEMA DE ALERTAS DE
# RAIOS](https://www.eletrica.ufpr.br/p/arquivostccs/689.pdf)
#
# - **Acurácia:** A acurácia é uma métrica utilizada para a avaliação do desempenho de modelos de classificação. Ela reflete a proporção de exemplos classificados corretamente em relação ao número total de exemplos (Abadi et al., 2015; Chollet et al., 2015; Géron, 2019). O cálculo da acurácia envolve a divisão do número de previsões corretas pelo número total de exemplos. A acurácia é dada por
#
#     - $Acc(\%) = 100 \times \frac{T_C}{T_N},$
#         onde $T_C$ é o total de classificações corretas e $T_N$ é o total de exemplos da base de dados.
# - **Precisão:** A precisão é uma métrica empregada na avaliação do desempenho de modelos de classificação, direcionando-se à qualidade das previsões positivas. Ela quantifica a proporção de exemplos corretamente classificados como positivos em relação ao total de exemplos classificados como positivos (Abadi et al., 2015; Chollet et al., 2015; Géron, 2019). a precisão é dada por:
#
#     - $P(\%) = 100 \times \frac{T_P}{T_P+F_P},$ no qual $T_P$ é o total de classificações positivas verdadeiras e $F_P$ é o total de classificações positivas falsas, para a classe considerada.
# - **Recall:** O *recall*, que também é conhecido como sensibilidade ou taxa de verdadeiros positivos, representa uma métrica empregada para avaliar o desempenho de um modelo de classificação, principalmente em relação à classe positiva. Essa métrica quantifica a proporção de exemplos positivos que o modelo identificou corretamente em relação ao total de exemplos verdadeiramente positivos (Géron, 2019). O recall é dado por:
#
# 	- $R(\%) = 100 \times \frac{T_P}{T_P+F_N},$	sendo $T_P$ o total de classificações positivas verdadeiras e $F_N$ o total de classificações negativas falsas, para a classe considerada.
# - **F1 Score:** O F1-score é uma métrica de avaliação que combina as métricas de precisão e recall em um único valor. É especialmente útil quando as classes estão desbalanceadas, ou seja, quando há uma diferença significativa entre o número de exemplos positivos e negativos (Abadi et al., 2015; Géron, 2019). O F1-score é calculado a partir da média harmônica da precisão e do recall, e é dado pela fórmula:
#     - 	$F_1 = 2 \times \frac{P \times R}{P + R},$ onde $P$ e $R$ são respectivamente a precisão e o \textit{recall}.
# - **Matriz de Confusão:** A matriz de confusão (Géron, 2019) é uma ferramenta comum para avaliar o desempenho de modelos de classificação. Ela exibe contagens de instâncias classificadas corretamente e incorretamente para cada classe em uma tabela de dimensão $N \times N$, onde N é o número de classes. As linhas representam as classes reais, as colunas representam as classes previstas. A matriz fornece informações sobre verdadeiros positivos ($T_P$), falsos positivos ($F_P$), falsos negativos ($F_N$) e verdadeiros negativos ($T_N$), usados para calcular métricas como precisão, *recall*, *F1-score*, e mais. A matriz de confusão ajuda a identificar erros do modelo, como confusões entre classes semelhantes, informando ajustes necessários para melhorar a classificação.

# %%
# Funções extraídas de meu saudoso TCC

classes_to_code = {"Tumor Benigno": 0,
                   "Tumor Maligno": 1}

def get_acc(y_true,
            y_pred):
    """
        Wrapper simples de cálculo de acurácia
        Args:
            y_true (ndarray): saída real
            y_pred (ndarray): saída predita
        Returns: 
            res_acc (ndarray): os resultados para cálculo da acurácia geral
    """
    res_acc = np.zeros(len(y_true))
    res = y_pred == y_true
    res_acc[res == True] = 1
    return res


def get_tp(cf):
    """
        Computa os verdadeiros positivos a partir da matriz de confusão
        Args:
            cf (ndarray(n,n)): a matriz de confusão
        Returns:
            tps(ndarray(n)): os verdadeiros positivos extraídos da matriz de confusão
    """
    tps = [cf[i][i] for i in range(len(cf))]
    return np.array(tps)


def get_fp(cf):
    """
        Computa os falsos positivos a partir da matriz de confusão
        Args:
            cf (ndarray(n,n)): a matriz de confusão
        Returns:
            fps(ndarray(n)): os falsos positivos extraídos da matriz de confusão
    """
    fps = list()
    for i in range(len(cf)):
        cfp = 0
        for j in range(len(cf)):
            cfp += cf[j][i] if i != j else 0
        fps.append(cfp)
    return np.array(fps)


def get_fn(cf):
    """
        Computa os falsos negativos a partir da matriz de confusão
        Args:
            cf (ndarray(n,n)): a matriz de confusão
        Returns:
            tps(ndarray(n)): os falsos negativos extraídos da matriz de confusão
    """
    fps = list()
    for i in range(len(cf)):
        cfp = 0
        for j in range(len(cf)):
            cfp += cf[i][j] if i != j else 0
        fps.append(cfp)
    return np.array(fps)


def get_precision(tp, fp):
    """
        Computa o parâmetro precisão
        Args:
            tp (int): quantidade de verdadeiros positivos
            fp (int): quantidade de falsos positivos
        Returns:
            p (float): a precisão
    """
    p = tp / (tp + fp)
    return p


def get_recall(tp, fn):
    """
        Computa o parâmetro recall, sensibilidade ou recorrência
        Args:
            tp (int): quantidade de verdadeiros positivos
            fn (int): quantidade de falsos negativos
        Returns:
            r (float): o recall
    """
    r = tp / (tp + fn)
    return r


def get_f1_score(p, r):
    """
        Computa o F1-Score a partir da precisão e recall
        Args:
            p (float): a precisão
            r (float): a sensibilidade, recorrência ou recall
        Returns:
            p (float): a precisão
    """
    f1_score = 2 * (p * r) / (p + r)
    return f1_score


def get_performance_indexes(cf, classes_to_code, algo="Adam"):
    """
        Wrapper dos parâmetros de desempenho
        Args:
            cf (ndarray): a matriz de confusão
            classes_to_code (dict): as classes convertidas em texto
        Returns:
            p (float): a precisão
    """
        
    r_classes = [p for p in classes_to_code.keys()]
    ntp = get_tp(cf)
    nfp = get_fp(cf)
    fn = get_fn(cf)
    p = get_precision(ntp, nfp)
    r = get_recall(ntp, fn)
    f1_score = get_f1_score(p, r)
    p *= 100
    r *= 100
    
    performance = np.stack((ntp,
                            nfp,
                            fn,
                            p,
                            r,
                            f1_score), axis=0).T.copy().tolist()

    f_performance = list()
    for i in range(len(r_classes)):
        performance_row = [r_classes[i]] + ["{:.1f}".format(p) for p in performance[i]]
        performance_row.insert(0, f"{algo}")
        f_performance.append(performance_row)

    return f_performance

def confusion_matrix_np(y_true, y_pred, num_classes=None):
    """
        Calcula a matriz de confusão utilizando apenas NumPy - não vou carregar o tensorflow somente para isto.....
        
        Args:
            y_true (ndarray): saída real
            y_pred (ndarray): saída predita
            num_classes: número total de classes (opcional). Se não fornecido, será inferido automaticamente.
        
        Returns:
            conf_matrix (ndarray): a matriz de confusão
    """
    y_true = np.asarray(y_true)
    y_pred = np.asarray(y_pred)
    if num_classes is None:
        num_classes = int(np.max([y_true.max(), y_pred.max()])) + 1  # +1 pois as classes começam em 0
    
    conf_matrix = np.zeros((num_classes, num_classes), dtype=int)
    
    for true, pred in zip(y_true, y_pred):
        conf_matrix[int(true)][int(pred)] += 1
    
    return conf_matrix


def get_confusion_matrix(y_true,
                         y_pred,
                         commands):
    """
        Computa a matriz de confusão
        Args:
            y_true (ndarray): saída real
            y_pred (ndarray): saída predita
            commands (list): as classes de classificação
        Returns:
            confusion_latrix (list): a matriz de confusão
    """
    test_acc = np.sum(get_acc(y_true, y_pred)) / len(y_true)
    print(f'Test set accuracy: {test_acc:.2%}')
    confusion_mtx = confusion_matrix_np(y_true, y_pred)
    group_counts = ["{0: 0.0f}".format(value) for value in confusion_mtx.flatten()]
    group_percentages = list()
    for i in range(0, len(confusion_mtx)):
        rsum = np.sum(confusion_mtx[i])
        for j in range(0, len(confusion_mtx[i])):
            group_percentages.append("{0:.1f} %".format(100 * confusion_mtx[i][j] / rsum))
    labels = [f"{v2}\n{v3}" for v2, v3 in zip(group_counts, group_percentages)]
    labels = np.asarray(labels).reshape(len(commands), len(commands))
    plt.figure(figsize=(10, 8))
    sns.heatmap(confusion_mtx,
                xticklabels=commands,
                yticklabels=commands,
                annot=labels,
                fmt='',
                cmap='Blues',
                cbar_kws={'label': "$eventos$", 'orientation': 'vertical'})
    plt.title(f'Acurácia: {test_acc:.0%}')
    plt.xlabel('Evento Predito')
    plt.ylabel('Evento Real')
    plt.tight_layout()
    plt.show()

    return confusion_mtx

# %% [markdown]
# ##### Algoritmos de Otimização Complementares

# %%
# funções conhecidas de outros notebooks

def rmsprop_gdc(X, y, w_in, b_in, alpha, num_iters, calcula_custo, calcula_gradiente, beta=0.9, epsilon=1e-8): # gdc = versão Gugu Das Candonga
    """
        Aplica o método RMSProp para ajustar w, b para problemas multivariados.

        Argumentos da função:
            X (ndarray (m, n))  : Conjunto de dados com m exemplos e n características
            y (ndarray (m,))    : Valores alvo de saída
            w_in (ndarray (n,)) : Valores iniciais para os parâmetros w (vetor)
            b_in (escalar)      : Valor inicial para o parâmetro b
            alpha (float)       : Taxa de aprendizado
            num_iters (int)     : Número de iterações
            calcula_custo       : Função para calcular o custo
            calcula_gradiente   : Função para calcular o gradiente
            beta (float)        : Fator de decaimento para RMSProp (geralmente próximo de 0.9)
            epsilon (float)     : Pequeno valor para evitar divisão por zero no cálculo do gradiente (geralmente 1e-8)

        Retorna:
            w (ndarray (n,))    : Valor atualizado de w
            b (scalar)          : Valor atualizado de b
            J_history (list)    : Histórico dos valores de custo
    """

    # Inicializar variáveis
    J_history = []
    w = w_in
    b = b_in
    
    # Inicialização de acumuladores de gradiente como vetores do tamanho de w
    v_dw = 0.0  # Vetor do mesmo tamanho que w
    v_db = 0.0  # b é escalar

    for i in range(num_iters):
        # Calcula o gradiente
        dj_db, dj_dw = calcula_gradiente(X, y, w, b)

        # Atualiza os acumuladores RMSProp para w e b (element-wise para w)
        v_dw = beta * v_dw + (1 - beta) * (dj_dw**2)
        v_db = beta * v_db + (1 - beta) * (dj_db**2)

        # Atualiza os parâmetros w e b
        w = w - alpha * dj_dw / (np.sqrt(v_dw) + epsilon)
        b = b - alpha * dj_db / (np.sqrt(v_db) + epsilon)

        # Armazena o custo para cada iteração
        J_history.append(calcula_custo(X, y, w, b))
        
        # Exibe o progresso em intervalos regulares
        if i % (num_iters // 10) == 0 or i == num_iters - 1:
            print(f"Iteração {i:4d}: Custo {J_history[-1]:8.8f}")

    return w, b, J_history


def sgd_gdc(X, y, w_in, b_in, alpha, num_iters, calcula_custo, calcula_gradiente):  # gdc = versão Gugu Das Candonga
    """
        Aplica o Método do Gradiente Estocástico (SGD) para ajustar w, b.

        Argumentos da função:
            X (ndarray (m, n))   : Conjunto de dados com m exemplos e n características
            y (ndarray (m,))     : Valores alvo de saída
            w_in (ndarray (n,))  : Valores iniciais para os parâmetros w (vetor)
            b_in (scalar)        : Valor inicial para o parâmetro b
            alpha (float)        : Taxa de aprendizado
            num_iters (int)      : Número de iterações
            calcula_custo        : Função para calcular o custo
            calcula_gradiente    : Função para calcular o gradiente

        Retorna:
            w (ndarray (n,))     : Valor atualizado de w
            b (scalar)           : Valor atualizado de b
            J_history (list)     : Histórico dos valores de custo
    """

    # Inicializar variáveis
    J_history = []
    b = b_in
    w = w_in
    m = len(y)  # Número de amostras

    for i in range(num_iters):
        # Embaralhar os dados a cada iteração
        indices = np.random.permutation(m)
        X_shuffled = X[indices]
        y_shuffled = y[indices]

        # Atualiza w e b para cada exemplo de treinamento
        for j in range(m):
            # Seleciona uma única amostra (vetor de características e valor alvo)
            x_i = X_shuffled[j]   # Vetor (n,)
            y_i = y_shuffled[j]   # Escalar
            # print(np.array([x_i]), np.array([y_i]))
            # break
            # Calcula o gradiente para essa amostra
            dj_db, dj_dw = calcula_gradiente(np.array([x_i]), np.array([y_i]), w, b)
            # Atualiza os parâmetros w e b
            w = w - alpha * dj_dw
            b = b - alpha * dj_db

        # Armazena o custo após a passagem por todo o conjunto de dados
        J_history.append(calcula_custo(X, y, w, b))

        # Exibe o progresso em intervalos regulares
        if i % (num_iters // 10) == 0 or i == num_iters - 1:
            print(f"Iteração {i:4d}: Custo {J_history[-1]:8.8f}")

    return w, b, J_history


def gradiente_conjugado_gdc(x, y, w_in, b_in, alpha, num_iters, calcula_custo, calcula_gradiente, tol=1e-8):  # gdc = versão Gugu Das Candonga
    """
        Método de Gradiente Conjugado para ajuste de w e b.

        Argumentos:
            x (ndarray (m, n))  : Conjunto de dados com m amostras e n características
            y (ndarray (m,))    : Valores alvo de saída
            w_in (ndarray (n,)) : Vetor inicial para os parâmetros w
            b_in (scalar)       : Valor inicial para o parâmetro b
            alpha (float)       : Tamanho de passo ou taxa de aprendizado
            num_iters (int)     : Número de iterações
            calcula_custo       : Função para calcular o custo
            calcula_gradiente   : Função para calcular o gradiente
            tol (float)         : Tolerância para critério de parada

        Retorna:
            w (ndarray (n,))    : Valor atualizado de w
            b (scalar)          : Valor atualizado de b
            J_history (list)    : Histórico dos valores de custo
    """
    w = w_in
    b = b_in
    J_history = []

    g_prev_w = np.zeros(len(w))
    g_prev_b = 0
    p_w = -g_prev_w  # Inicializa como negativo do gradiente
    p_b = -g_prev_b

    for t in range(1, num_iters + 1):
        # Calcula o gradiente para w e b
        dj_db, dj_dw = calcula_gradiente(x, y, w, b)

        # Critério de parada baseado na norma do gradiente
        if np.sqrt(np.sum(dj_dw ** 2)) < tol and abs(dj_db) < tol:
            print(f"Convergência atingida na iteração {t}.")
            break

        # Primeira iteração - p inicial é o negativo do gradiente
        if t == 1:
            p_w = -dj_dw
            p_b = -dj_db
        else:
            # Computa beta_t usando o método Polak-Ribiére
            if np.dot(g_prev_w, g_prev_w) != 0:  # Prevenir divisão por zero
                beta_t = np.dot(dj_dw, dj_dw - g_prev_w) / np.dot(g_prev_w, g_prev_w)
            else:
                beta_t = 0  # Ou outra abordagem
            
            p_w = -dj_dw + beta_t * p_w
            p_b = -dj_db + beta_t * p_b

        # Atualiza os parâmetros
        w += alpha * p_w
        b += alpha * p_b

        # Calcula o custo e armazena no histórico
        J_history.append(calcula_custo(x, y, w, b))

        # Atualiza o gradiente anterior
        g_prev_w = dj_dw
        g_prev_b = dj_db

        # Exibe o progresso em intervalos regulares
        if t % (num_iters // 10) == 0 or t == num_iters - 1:
            print(f"Iteração {t:4d}: Custo {J_history[-1]:8.8f}")

    return w, b, J_history


def adam_gdc(x, y, w_in, b_in, alpha, beta1, beta2, epsilon, num_iters, calcula_custo, calcula_gradiente):  # gdc = versão Gugu Das Candonga
    """
        Aplica o algoritmo Adam para otimização de w e b em um cenário multivariado.

        Argumentos:
            x (ndarray): Conjunto de dados com m amostras e n características.
            y (ndarray): Valores alvo de saída.
            w_in (ndarray): Valores iniciais para os parâmetros w (vetor de pesos).
            b_in (scalar): Valor inicial para o parâmetro b (intercepto).
            alpha (float): Taxa de aprendizado.
            beta1 (float): Exponencial para a média dos gradientes.
            beta2 (float): Exponencial para a média dos gradientes ao quadrado.
            epsilon (float): Pequeno valor para evitar divisão por zero.
            num_iters (int): Número total de iterações.
            calcula_custo: Função que calcula o custo.
            calcula_gradiente: Função que calcula o gradiente.

        Retorna:
            w (ndarray): Valor otimizado de w (vetor de pesos).
            b (scalar): Valor otimizado de b (intercepto).
            J_history (list): Histórico dos valores de custo.
    """
    w = w_in
    b = b_in
    m_w, v_w = 0, 0  # Inicialização dos momentos de w
    m_b, v_b = 0, 0  # Inicialização dos momentos de b

    J_history = []

    for t in range(1, num_iters + 1):
        # Calcula o gradiente
        dj_db, dj_dw = calcula_gradiente(x, y, w, b)

        # Atualiza as médias e variâncias dos gradientes (momentos)
        m_w = beta1 * m_w + (1 - beta1) * dj_dw
        m_b = beta1 * m_b + (1 - beta1) * dj_db

        v_w = beta2 * v_w + (1 - beta2) * (dj_dw ** 2)
        v_b = beta2 * v_b + (1 - beta2) * (dj_db ** 2)

        # Correções de bias
        m_w_corrigido = m_w / (1 - beta1 ** t)
        m_b_corrigido = m_b / (1 - beta1 ** t)
        v_w_corrigido = v_w / (1 - beta2 ** t)
        v_b_corrigido = v_b / (1 - beta2 ** t)

        # Atualiza os parâmetros
        w -= alpha * (m_w_corrigido / (np.sqrt(v_w_corrigido) + epsilon))
        b -= alpha * (m_b_corrigido / (np.sqrt(v_b_corrigido) + epsilon))

        # Armazena o custo atual
        J_history.append(calcula_custo(x, y, w, b))
        
        # Exibe o progresso em intervalos regulares
        if t % (num_iters // 10) == 0 or t == num_iters - 1:
            print(f"Iteração {t:4d}: Custo {J_history[-1]:8.8f}   ")

    return w, b, J_history

# %% [markdown]
# ##### Geração de Dados

# %%
# vamos manter a curva de fronteira, apenas randomizando pontos em um quadrado, para fins didáticos
min_value = 0
max_value = -b_final_gdc/w_final_gdc[0] # para dar uma equilibrada na base de dados - não quero ter surpresas com dataset desequilibrado
num_points = 5000
sigma = 0.05
mu = 0
tabela = list()
tabela_coefs = list()

# gerando os dados do tumor
rng = np.random.default_rng(12345) # semente informada, para a reprodução do resultado
x_trein = rng.uniform(min_value, max_value, (num_points, 2))

# simulando a tabela verdade, para fins de treinamento
z = np.dot(x_trein, w_final_gdc) + b_final_gdc
logit_results = sigmoide(z)
y_trein = np.zeros(num_points)
y_trein[logit_results > 0.5] = 1
pos = y_trein == 1 # identifica os elementos em y que são iguais a 1
neg = y_trein == 0 # identifica os elementos em y que são iguais a 0

# aproveitando para adicionar um ruído leve - deve causar falsos positivos e falsos negativos na matriz de confusão

rng = np.random.default_rng(12345) # semente informada, para a reprodução do resultado
x_trein += rng.normal(mu, sigma, x_trein.shape)

# dados de teste
rng = np.random.default_rng(54321) # semente informada, para a reprodução do resultado
x_test = rng.uniform(min_value, max_value, (num_points, 2))

# simulando a tabela verdade de teste - dados diferentes do dataset de treinamento
z = np.dot(x_test, w_final_gdc) + b_final_gdc
logit_results = sigmoide(z)
y_test = np.zeros(num_points)
y_test[logit_results > 0.5] = 1
rng = np.random.default_rng(54321) # semente informada, para a reprodução do resultado
x_test += rng.normal(mu, sigma, x_trein.shape)

# Fronteira de decisão
x0 = -b_final_gdc/w_final_gdc[0]
x1 = -b_final_gdc/w_final_gdc[1]

fig,ax = plt.subplots(1,1,figsize=(10,8))

# Plotando a Fronteira de Decisão
ax.plot([0,x0],[x1,0], c="k")
ax.axis([0, 4, 0, 3.5]) # limitando o display do gráfico

# Preenche a região abaixo da linha
ax.fill_between([0,x0],[x1,0])

# Plotando os dados também:
ax.scatter(x_trein[pos,0], x_trein[pos,1], marker='x', s=80, c = 'red', label="y=1", alpha=0.5)
ax.scatter(x_trein[neg,0], x_trein[neg,1], marker='^', s=100, label="y=0", facecolors='none',
              edgecolors='b',lw=3, alpha=0.2)

ax.set_ylabel('$x_1$')
ax.set_xlabel('$x_0$')
plt.show()

# %% [markdown]
# ##### Regressão Logística - Método do Gradiente - Método da Aula

# %%
w_tmp     = np.zeros_like(x_trein[0])
b_tmp     = 0.
alpha     = 0.5 # otimizado usando VC (Vai Cavalo!!!!)
iteracoes = 10000

start_time = time.time()

w_final_gdc, b_final_gdc, J_Hist_gdc = metodo_do_gradiente_RegLog(x_trein, y_trein, w_tmp, b_tmp, alpha, iteracoes)

stop_time = time.time()
execution_time = stop_time - start_time

print(f"b,w encontrados pelo método do gradiente (Aula): {b_final_gdc:0.8f},{w_final_gdc} ")

# normalização de parâmetros - magnitude do vetor
mag = np.sqrt(np.sum(w_final_gdc ** 2) + b_final_gdc ** 2)

w_final_gdc_normalized = w_final_gdc / mag

b_final_gdc_normalized = b_final_gdc / mag

# coletando os dados de treinamento

model_data = ["Método do Gradiente (Aula)", 
              execution_time,               
              iteracoes,
              execution_time / iteracoes,
              b_final_gdc, 
              w_final_gdc[0], 
              w_final_gdc[1],
              b_final_gdc_normalized,
              w_final_gdc_normalized[0],
              w_final_gdc_normalized[1]]

tabela_coefs.append(model_data)

# Plotando os resultados da otimização

fig,ax = plt.subplots(1, 1, constrained_layout=True, figsize=(10, 8))
ax.plot(J_Hist_gdc)
ax.set_title("Custo vs. iteração - Método do Gradiente (Aula)")
ax.set_ylabel('Custo')
ax.set_xlabel('iteração')
plt.show()
# Out:
# Iteração    0: Custo 0.668845616392916
# Iteração 1000: Custo 0.1501624928319008
# Iteração 2000: Custo 0.12128517875388274
# Iteração 3000: Custo 0.10776898004843401
# Iteração 4000: Custo 0.09944411379233814
# Iteração 5000: Custo 0.09363829913216751
# Iteração 6000: Custo 0.08928727845761858
# Iteração 7000: Custo 0.08586902654223201
# Iteração 8000: Custo 0.08309236104486847
# Iteração 9000: Custo 0.08077990885229071
# b,w encontrados pelo método do gradiente (Aula): -25.15280576,[9.33689017 8.93963533]

# %% [markdown]
# ##### Fronteira de Decisão - Método do Gradiente - Método da Aula

# %%
# Fronteira de decisão
x0 = -b_final_gdc/w_final_gdc[0]
x1 = -b_final_gdc/w_final_gdc[1]

fig,ax = plt.subplots(1,1,figsize=(10,8))

# Plotando a Fronteira de Decisão
ax.plot([0,x0],[x1,0], c="k")
ax.axis([0, 4, 0, 3.5]) # limitando o display do gráfico

# Preenche a região abaixo da linha
ax.fill_between([0,x0],[x1,0])

# Plotando os dados também:
ax.scatter(x_trein[pos,0], x_trein[pos,1], marker='x', s=80, c = 'red', label="y=1", alpha=0.5)
ax.scatter(x_trein[neg,0], x_trein[neg,1], marker='^', s=100, label="y=0", facecolors='none',
              edgecolors='b',lw=3, alpha=0.2)
ax.set_title("Fronteira de Decisão - Método do Gradiente (Aula)")

ax.set_ylabel('$x_1$')
ax.set_xlabel('$x_0$')
plt.show()

# %% [markdown]
# ##### Matriz de Confusão - Método do Gradiente - Método da Aula

# %%
# "classificando" em função da probabilidade
z = np.dot(x_test, w_final_gdc) + b_final_gdc
logit_results = sigmoide(z)
y_pred = np.zeros(len(logit_results))
y_pred[logit_results > 0.5] = 1
confusion_mtx = get_confusion_matrix(y_test, y_pred, classes_to_code)
# Out:
# Test set accuracy: 97.90%

# %% [markdown]
# ##### Parâmetros de Desempenho - Método do Gradiente - Método da Aula

# %%
tabela += get_performance_indexes(confusion_mtx, classes_to_code, "Método do Gradiente (Aula)")

# %% [markdown]
# ##### Regressão Logística - Método do Gradiente - GDC

# %%
w_tmp     = np.zeros_like(x_trein[0])
b_tmp     = 0.
alpha     = 0.5 # otimizado usando VC (Vai Cavalo!!!!)
iteracoes = 10000

start_time = time.time()

w_final_gdc, b_final_gdc, J_Hist_gdc = metodo_do_gradiente_gdc(x_trein, 
                                                               y_trein, 
                                                               w_tmp, 
                                                               b_tmp, 
                                                               calcula_custo_gdc, 
                                                               calcula_gradiente_gdc, 
                                                               alpha, 
                                                               iteracoes)
stop_time = time.time()
execution_time = stop_time - start_time

print(f"b,w encontrados pelo método do gradiente (GDC): {b_final:0.8f},{w_final} ")

# normalização de parâmetros - magnitude do vetor
mag = np.sqrt(np.sum(w_final_gdc ** 2) + b_final_gdc ** 2)

w_final_gdc_normalized = w_final_gdc / mag

b_final_gdc_normalized = b_final_gdc / mag

# coletando os dados de treinamento

model_data = ["Método do Gradiente (GDC)", 
              execution_time,               
              iteracoes,
              execution_time / iteracoes,
              b_final_gdc, 
              w_final_gdc[0], 
              w_final_gdc[1],
              b_final_gdc_normalized,
              w_final_gdc_normalized[0],
              w_final_gdc_normalized[1]]

tabela_coefs.append(model_data)

# Plotando os resultados da otimização

fig,ax = plt.subplots(1, 1, constrained_layout=True, figsize=(10, 8))
ax.plot(J_Hist_gdc)
ax.set_title("Custo vs. iteração - Método do Gradiente (GDC)")
ax.set_ylabel('Custo')
ax.set_xlabel('iteração')
plt.show()
# Out:
# Iteração    0: Custo 0.66884562
# Iteração 1000: Custo 0.15016249
# Iteração 2000: Custo 0.12128518
# Iteração 3000: Custo 0.10776898
# Iteração 4000: Custo 0.09944411
# Iteração 5000: Custo 0.09363830
# Iteração 6000: Custo 0.08928728
# Iteração 7000: Custo 0.08586903
# Iteração 8000: Custo 0.08309236
# Iteração 9000: Custo 0.08077991
# b,w encontrados pelo método do gradiente (GDC): -14.22240998,[5.28123029 5.07815608]

# %% [markdown]
# ##### Fronteira de Decisão - Método do Gradiente (GDC)

# %%
# Fronteira de decisão
x0 = -b_final_gdc/w_final_gdc[0]
x1 = -b_final_gdc/w_final_gdc[1]

fig,ax = plt.subplots(1,1,figsize=(10,8))

# Plotando a Fronteira de Decisão
ax.plot([0,x0],[x1,0], c="k")
ax.axis([0, 4, 0, 3.5]) # limitando o display do gráfico

# Preenche a região abaixo da linha
ax.fill_between([0,x0],[x1,0])

# Plotando os dados também:
ax.scatter(x_trein[pos,0], x_trein[pos,1], marker='x', s=80, c = 'red', label="y=1", alpha=0.5)
ax.scatter(x_trein[neg,0], x_trein[neg,1], marker='^', s=100, label="y=0", facecolors='none',
              edgecolors='b',lw=3, alpha=0.2)
ax.set_title("Fronteira de Decisão - Método do Gradiente (GDC)")

ax.set_ylabel('$x_1$')
ax.set_xlabel('$x_0$')
plt.show()

# %% [markdown]
# ##### Matriz de Confusão - Método do Gradiente (GDC)

# %%
# "classificando" em função da probabilidade
z = np.dot(x_test, w_final_gdc) + b_final_gdc
logit_results = sigmoide(z)
y_pred = np.zeros(len(logit_results))
y_pred[logit_results > 0.5] = 1
confusion_mtx = get_confusion_matrix(y_test, y_pred, classes_to_code)
# Out:
# Test set accuracy: 97.90%

# %% [markdown]
# ##### Parâmetros de Desempenho - Método do Gradiente (GDC)

# %%
tabela += get_performance_indexes(confusion_mtx, classes_to_code, "Método do Gradiente (GDC)")

# %% [markdown]
# ##### Regressão Logística - RMSProp

# %%
w_tmp     = np.zeros_like(x_trein[0])
b_tmp     = 0.0
iteracoes = 1000
alpha = 0.065

start_time = time.time()

w_final_gdc, b_final_gdc, J_Hist_gdc = rmsprop_gdc(x_trein,
                                                   y_trein, 
                                                   w_tmp, 
                                                   b_tmp,
                                                   alpha,
                                                   iteracoes, 
                                                   calcula_custo_gdc, 
                                                   calcula_gradiente_gdc)

stop_time = time.time()
execution_time = stop_time - start_time

print(f"b,w encontrados pelo RMSProp: {b_final_gdc:0.8f},{w_final_gdc} ")

# normalização de parâmetros - magnitude do vetor
mag = np.sqrt(np.sum(w_final_gdc ** 2) + b_final_gdc ** 2)

w_final_gdc_normalized = w_final_gdc / mag

b_final_gdc_normalized = b_final_gdc / mag

# coletando os dados de treinamento

model_data = ["RMSProp", 
              execution_time,               
              iteracoes,
              execution_time / iteracoes,
              b_final_gdc, 
              w_final_gdc[0], 
              w_final_gdc[1],
              b_final_gdc_normalized,
              w_final_gdc_normalized[0],
              w_final_gdc_normalized[1]]

tabela_coefs.append(model_data)


# Plotando os resultados da otimização
fig,ax = plt.subplots(1, 1, constrained_layout=True, figsize=(10, 8))
ax.plot(J_Hist_gdc)
ax.set_title("Custo vs. iteração - RMSProp")
ax.set_ylabel('Custo')
ax.set_xlabel('iteração')
plt.show()
# Out:
# Iteração    0: Custo 0.63491615
# Iteração  100: Custo 0.22980951
# Iteração  200: Custo 0.14975332
# Iteração  300: Custo 0.11847686
# Iteração  400: Custo 0.10213764
# Iteração  500: Custo 0.09201285
# Iteração  600: Custo 0.08508101
# Iteração  700: Custo 0.08002291
# Iteração  800: Custo 0.07616615
# Iteração  900: Custo 0.07312943
# Iteração  999: Custo 0.07070013
# b,w encontrados pelo RMSProp: -29.92129775,[11.06441983 10.58802838]

# %% [markdown]
# ##### Fronteira de Decisão - RMSProp

# %%
# Fronteira de decisão
x0 = -b_final_gdc/w_final_gdc[0]
x1 = -b_final_gdc/w_final_gdc[1]

fig,ax = plt.subplots(1,1,figsize=(10,8))

# Plotando a Fronteira de Decisão
ax.plot([0,x0],[x1,0], c="k")
ax.axis([0, 4, 0, 3.5]) # limitando o display do gráfico

# Preenche a região abaixo da linha
ax.fill_between([0,x0],[x1,0])

# Plotando os dados também:
ax.scatter(x_trein[pos,0], x_trein[pos,1], marker='x', s=80, c = 'red', label="y=1", alpha=0.5)
ax.scatter(x_trein[neg,0], x_trein[neg,1], marker='^', s=100, label="y=0", facecolors='none',
              edgecolors='b',lw=3, alpha=0.2)
ax.set_title("Fronteira de Decisão - RMSProp")

ax.set_ylabel('$x_1$')
ax.set_xlabel('$x_0$')
plt.show()

# %% [markdown]
# ##### Matriz de Confusão - RMSProp

# %%
# "classificando" em função da probabilidade
z = np.dot(x_test, w_final_gdc) + b_final_gdc
logit_results = sigmoide(z)
y_pred = np.zeros(len(logit_results))
y_pred[logit_results > 0.5] = 1
confusion_mtx = get_confusion_matrix(y_test, y_pred, classes_to_code)
# Out:
# Test set accuracy: 97.88%

# %% [markdown]
# ##### Parâmetros de Desempenho - RMSProp

# %%
tabela += get_performance_indexes(confusion_mtx, classes_to_code, "RMSProp")

# %% [markdown]
# ##### Regressão Logística - SGD

# %%
w_tmp     = np.zeros_like(x_trein[0])
b_tmp     = 0.0
iteracoes = 500
alpha = 0.001

start_time = time.time()

w_final_gdc, b_final_gdc, J_Hist_gdc = sgd_gdc(x_trein,
                                               y_trein, 
                                               w_tmp, 
                                               b_tmp,
                                               alpha,
                                               iteracoes, 
                                               calcula_custo_gdc, 
                                               calcula_gradiente_gdc)

stop_time = time.time()
execution_time = stop_time - start_time

print(f"b,w encontrados pelo SGD: {b_final_gdc:0.8f},{w_final_gdc} ")

# normalização de parâmetros - magnitude do vetor
mag = np.sqrt(np.sum(w_final_gdc ** 2) + b_final_gdc ** 2)

w_final_gdc_normalized = w_final_gdc / mag

b_final_gdc_normalized = b_final_gdc / mag

# coletando os dados de treinamento

model_data = ["SGD", 
              execution_time,               
              iteracoes,
              execution_time / iteracoes,
              b_final_gdc, 
              w_final_gdc[0], 
              w_final_gdc[1],
              b_final_gdc_normalized,
              w_final_gdc_normalized[0],
              w_final_gdc_normalized[1]]

tabela_coefs.append(model_data)


# Plotando os resultados da otimização
fig,ax = plt.subplots(1, 1, constrained_layout=True, figsize=(10, 8))
ax.plot(J_Hist_gdc)
ax.set_title("Custo vs. iteração - SGD")
ax.set_ylabel('Custo')
ax.set_xlabel('iteração')
plt.show()
# Out:
# Iteração    0: Custo 0.59570009
# Iteração   50: Custo 0.18744613
# Iteração  100: Custo 0.14979070
# Iteração  150: Custo 0.13208862
# Iteração  200: Custo 0.12114708
# Iteração  250: Custo 0.11347408
# Iteração  300: Custo 0.10768360
# Iteração  350: Custo 0.10312757
# Iteração  400: Custo 0.09939834
# Iteração  450: Custo 0.09627059
# Iteração  499: Custo 0.09364395
# b,w encontrados pelo SGD: -19.79350939,[7.34538475 7.03933663]

# %% [markdown]
# ##### Fronteira de Decisão - SGD

# %%
# Fronteira de decisão
x0 = -b_final_gdc/w_final_gdc[0]
x1 = -b_final_gdc/w_final_gdc[1]

fig,ax = plt.subplots(1,1,figsize=(10,8))

# Plotando a Fronteira de Decisão
ax.plot([0,x0],[x1,0], c="k")
ax.axis([0, 4, 0, 3.5]) # limitando o display do gráfico

# Preenche a região abaixo da linha
ax.fill_between([0,x0],[x1,0])

# Plotando os dados também:
ax.scatter(x_trein[pos,0], x_trein[pos,1], marker='x', s=80, c = 'red', label="y=1", alpha=0.5)
ax.scatter(x_trein[neg,0], x_trein[neg,1], marker='^', s=100, label="y=0", facecolors='none',
              edgecolors='b',lw=3, alpha=0.2)
ax.set_title("Fronteira de Decisão - SGD")

ax.set_ylabel('$x_1$')
ax.set_xlabel('$x_0$')
plt.show()

# %% [markdown]
# ##### Matriz de Confusão - SGD

# %%
# "classificando" em função da probabilidade
z = np.dot(x_test, w_final_gdc) + b_final_gdc
logit_results = sigmoide(z)
y_pred = np.zeros(len(logit_results))
y_pred[logit_results > 0.5] = 1
confusion_mtx = get_confusion_matrix(y_test, y_pred, classes_to_code)
# Out:
# Test set accuracy: 97.88%

# %% [markdown]
# ##### Parâmetros de Desempenho - SGD

# %%
tabela += get_performance_indexes(confusion_mtx, classes_to_code, "SGD")

# %% [markdown]
# ##### Regressão Logística - Gradiente Conjugado

# %%
w_tmp     = np.zeros_like(x_trein[0])
b_tmp     = 0.0
iteracoes = 2000
alpha = 0.5 # otimizado usando VC (Vai Cavalo!!!)

start_time = time.time()

w_final_gdc, b_final_gdc, J_Hist_gdc = gradiente_conjugado_gdc(x_trein,
                                                               y_trein, 
                                                               w_tmp, 
                                                               b_tmp,
                                                               alpha,
                                                               iteracoes,
                                                               calcula_custo_gdc,
                                                               calcula_gradiente_gdc)


stop_time = time.time()
execution_time = stop_time - start_time

print(f"b,w encontrados pelo Gradiente Conjugado: {b_final_gdc:0.8f},{w_final_gdc} ")
# Coletando os dados de treinamento

# normalização de parâmetros - magnitude do vetor
mag = np.sqrt(np.sum(w_final_gdc ** 2) + b_final_gdc ** 2)

w_final_gdc_normalized = w_final_gdc / mag

b_final_gdc_normalized = b_final_gdc / mag

# coletando os dados de treinamento

model_data = ["Gradiente Conjugado", 
              execution_time, 
              iteracoes,
              execution_time / iteracoes,
              b_final_gdc, 
              w_final_gdc[0], 
              w_final_gdc[1],
              b_final_gdc_normalized,
              w_final_gdc_normalized[0],
              w_final_gdc_normalized[1]]

tabela_coefs.append(model_data)


# Plotando os resultados da otimização
fig,ax = plt.subplots(1, 1, constrained_layout=True, figsize=(10, 8))
ax.plot(J_Hist_gdc)
ax.set_title("Custo vs. iteração - Gradiente Conjugado")
ax.set_ylabel('Custo')
ax.set_xlabel('iteração')
plt.show()
# Out:
# Iteração  200: Custo 0.26097162
# Iteração  400: Custo 0.20398461
# Iteração  600: Custo 0.17769025
# Iteração  800: Custo 0.16159221
# Iteração 1000: Custo 0.15036885
# Iteração 1200: Custo 0.14193343
# Iteração 1400: Custo 0.13527472
# Iteração 1600: Custo 0.12983377
# Iteração 1800: Custo 0.12527238
# Iteração 1999: Custo 0.12139002
# Iteração 2000: Custo 0.12137190
# b,w encontrados pelo Gradiente Conjugado: -14.14912639,[5.25375765 5.04063413]

# %% [markdown]
# ##### Fronteira de Decisão - Gradiente Conjugado

# %%
# Fronteira de decisão
x0 = -b_final_gdc/w_final_gdc[0]
x1 = -b_final_gdc/w_final_gdc[1]

fig,ax = plt.subplots(1,1,figsize=(10,8))

# Plotando a Fronteira de Decisão
ax.plot([0,x0],[x1,0], c="k")
ax.axis([0, 4, 0, 3.5]) # limitando o display do gráfico

# Preenche a região abaixo da linha
ax.fill_between([0,x0],[x1,0])

# Plotando os dados também:
ax.scatter(x_trein[pos,0], x_trein[pos,1], marker='x', s=80, c = 'red', label="y=1", alpha=0.5)
ax.scatter(x_trein[neg,0], x_trein[neg,1], marker='^', s=100, label="y=0", facecolors='none',
              edgecolors='b',lw=3, alpha=0.2)
ax.set_title("Fronteira de Decisão - Gradiente Conjugado")

ax.set_ylabel('$x_1$')
ax.set_xlabel('$x_0$')
plt.show()

# %% [markdown]
# ##### Matriz de Confusão - Gradiente Conjugado

# %%
# "classificando" em função da probabilidade
z = np.dot(x_test, w_final_gdc) + b_final_gdc
logit_results = sigmoide(z)
y_pred = np.zeros(len(logit_results))
y_pred[logit_results > 0.5] = 1
confusion_mtx = get_confusion_matrix(y_test, y_pred, classes_to_code)
# Out:
# Test set accuracy: 97.88%

# %% [markdown]
# ##### Parâmetros de Desempenho - Gradiente Conjugado

# %%
tabela += get_performance_indexes(confusion_mtx, classes_to_code, "Gradiente Conjugado")

# %% [markdown]
# ##### Regressão Logística - Adam

# %%
w_tmp     = np.zeros_like(x_trein[0])
b_tmp     = 0.0
iteracoes = 1000
alpha  = 0.08 # otimizado usando VC (Vai Cavalo)
beta1 = 0.9 # otimizado usando VC (Vai Cavalo)
beta2 = 0.999 # otimizado usando VC (Vai Cavalo)
epsilon = 1e-8 # otimizado usando VC (Vai Cavalo)

start_time = time.time()

w_final_gdc, b_final_gdc, J_Hist_gdc = adam_gdc(x_trein,
                                                y_trein,
                                                w_tmp,
                                                b_tmp,
                                                alpha,
                                                beta1,
                                                beta2,
                                                epsilon,
                                                iteracoes,
                                                calcula_custo_gdc,
                                                calcula_gradiente_gdc)


stop_time = time.time()
execution_time = stop_time - start_time

print(f"b,w encontrados pelo Adam: {b_final_gdc:0.8f},{w_final_gdc} ")

# normalização de parâmetros - magnitude do vetor
mag = np.sqrt(np.sum(w_final_gdc ** 2) + b_final_gdc ** 2)

w_final_gdc_normalized = w_final_gdc / mag

b_final_gdc_normalized = b_final_gdc / mag

# coletando os dados de treinamento

model_data = ["Adam", 
              execution_time,              
              iteracoes,
              execution_time / iteracoes, 
              b_final_gdc, 
              w_final_gdc[0], 
              w_final_gdc[1],
              b_final_gdc_normalized,
              w_final_gdc_normalized[0],
              w_final_gdc_normalized[1]]

tabela_coefs.append(model_data)


# Plotando os resultados da otimização
fig,ax = plt.subplots(1, 1, constrained_layout=True, figsize=(10, 8))
ax.plot(J_Hist_gdc)
ax.set_title("Custo vs. iteração - Adam")
ax.set_ylabel('Custo')
ax.set_xlabel('iteração')
plt.show()
# Out:
# Iteração  100: Custo 0.24528226
# Iteração  200: Custo 0.17886639
# Iteração  300: Custo 0.14892966
# Iteração  400: Custo 0.13093592
# Iteração  500: Custo 0.11860854
# Iteração  600: Custo 0.10949977
# Iteração  700: Custo 0.10242877
# Iteração  800: Custo 0.09674556
# Iteração  900: Custo 0.09205849
# Iteração  999: Custo 0.08815179
# Iteração 1000: Custo 0.08811543
# b,w encontrados pelo Adam: -21.48911159,[7.97929883 7.64230885]

# %% [markdown]
# ##### Fronteira de Decisão - Adam

# %%
# Fronteira de decisão
x0 = -b_final_gdc/w_final_gdc[0]
x1 = -b_final_gdc/w_final_gdc[1]

fig,ax = plt.subplots(1,1,figsize=(10,8))

# Plotando a Fronteira de Decisão
ax.plot([0,x0],[x1,0], c="k")
ax.axis([0, 4, 0, 3.5]) # limitando o display do gráfico

# Preenche a região abaixo da linha
ax.fill_between([0,x0],[x1,0])

# Plotando os dados também:
ax.scatter(x_trein[pos,0], x_trein[pos,1], marker='x', s=80, c = 'red', label="y=1", alpha=0.5)
ax.scatter(x_trein[neg,0], x_trein[neg,1], marker='^', s=100, label="y=0", facecolors='none',
              edgecolors='b',lw=3, alpha=0.2)
ax.set_title("Fronteira de Decisão - Adam")

ax.set_ylabel('$x_1$')
ax.set_xlabel('$x_0$')
plt.show()

# %% [markdown]
# ##### Matriz de Confusão - Adam

# %%
# "classificando" em função da probabilidade
z = np.dot(x_test, w_final_gdc) + b_final_gdc
logit_results = sigmoide(z)
y_pred = np.zeros(len(logit_results))
y_pred[logit_results > 0.5] = 1
confusion_mtx = get_confusion_matrix(y_test, y_pred, classes_to_code)
# Out:
# Test set accuracy: 97.88%

# %% [markdown]
# ##### Parâmetros de Desempenho - Adam

# %%
tabela += get_performance_indexes(confusion_mtx, classes_to_code, "Adam")

# %% [markdown]
# ##### Regressão Logística - SKLearn

# %%
modelo_logit = LogisticRegression()

start_time = time.time()

modelo_logit.fit(x_trein, y_trein)

stop_time = time.time()
execution_time = stop_time - start_time
b_final_gdc = float(modelo_logit.intercept_[0])
w_final_gdc = modelo_logit.coef_.flatten()
print(f"b,w encontrados pelo SKLearn: {b_final_gdc:0.8f},{w_final_gdc} ")

# normalização de parâmetros - magnitude do vetor
mag = np.sqrt(np.sum(w_final_gdc ** 2) + b_final_gdc ** 2)

w_final_gdc_normalized = w_final_gdc / mag

b_final_gdc_normalized = b_final_gdc / mag

iteracoes = modelo_logit.n_iter_

# coletando os dados de treinamento

model_data = ["SKLearn", 
              execution_time,               
              iteracoes,
              execution_time / iteracoes,
              b_final_gdc, 
              w_final_gdc[0], 
              w_final_gdc[1],
              b_final_gdc_normalized,
              w_final_gdc_normalized[0],
              w_final_gdc_normalized[1]]

tabela_coefs.append(model_data)
# Out:
# b,w encontrados pelo SKLearn: -29.13012610,[10.79949593 10.34173272]

# %% [markdown]
# ##### Fronteira de Decisão - SKLearn

# %%
# Fronteira de decisão
x0 = -b_final_gdc/w_final_gdc[0]
x1 = -b_final_gdc/w_final_gdc[1]

fig,ax = plt.subplots(1,1,figsize=(10,8))

# Plotando a Fronteira de Decisão
ax.plot([0,x0],[x1,0], c="k")
ax.axis([0, 4, 0, 3.5]) # limitando o display do gráfico

# Preenche a região abaixo da linha
ax.fill_between([0,x0],[x1,0])

# Plotando os dados também:
ax.scatter(x_trein[pos,0], x_trein[pos,1], marker='x', s=80, c = 'red', label="y=1", alpha=0.5)
ax.scatter(x_trein[neg,0], x_trein[neg,1], marker='^', s=100, label="y=0", facecolors='none',
              edgecolors='b',lw=3, alpha=0.2)
ax.set_title("Fronteira de Decisão - SKLearn")

ax.set_ylabel('$x_1$')
ax.set_xlabel('$x_0$')
plt.show()

# %% [markdown]
# ##### Matriz de Confusão - SKLearn

# %%
y_pred = modelo_logit.predict(x_test)
confusion_mtx = get_confusion_matrix(y_test, y_pred, classes_to_code)
# Out:
# Test set accuracy: 97.90%

# %% [markdown]
# ##### Parâmetros de Desempenho - SKLearn

# %%
tabela += get_performance_indexes(confusion_mtx, classes_to_code, "SKLearn")

# %% [markdown]
# ##### Desempenho dos algoritmos

# %%
header = ["Algoritmo", "Classe", "$T_P$", "$F_P$", "$F_N$", "$P(\%)$", "$R(\%)$", "$F_1$ Score"]
print(tabulate(tabela,
               headers=header,
               tablefmt='pipe'))
print()
header = ["Algoritmo", "$T_e$(s)", "$N$", "$\\frac{T_e}{N}$", "$b$", "$w_0$", "$w_1$", "$b_n$", "$w_{0_n}$", "$w_{1_n}$"]
print(tabulate(tabela_coefs,
               headers=header,
               tablefmt='pipe'))
# Out:
# | Algoritmo                  | Classe        |   $T_P$ |   $F_P$ |   $F_N$ |   $P(\%)$ |   $R(\%)$ |   $F_1$ Score |
# |:---------------------------|:--------------|--------:|--------:|--------:|----------:|----------:|--------------:|
# | Método do Gradiente (Aula) | Tumor Benigno |    2588 |      50 |      55 |      98.1 |      97.9 |             1 |
# | Método do Gradiente (Aula) | Tumor Maligno |    2307 |      55 |      50 |      97.7 |      97.9 |             1 |
# | Método do Gradiente (GDC)  | Tumor Benigno |    2588 |      50 |      55 |      98.1 |      97.9 |             1 |
# | Método do Gradiente (GDC)  | Tumor Maligno |    2307 |      55 |      50 |      97.7 |      97.9 |             1 |
# | RMSProp                    | Tumor Benigno |    2600 |      63 |      43 |      97.6 |      98.4 |             1 |
# | RMSProp                    | Tumor Maligno |    2294 |      43 |      63 |      98.2 |      97.3 |             1 |
# ...
